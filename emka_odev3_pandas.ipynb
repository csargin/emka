# %% [markdown]
# <a href="https://colab.research.google.com/github/csargin/emka/blob/main/emka_odev3_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ödev 1

# %% [markdown]
# 1) İndexlerinde "Breaking Bad" , "Chernobyl" , "Leyla ile Mecnun" , "X-Men"  , "Captain America"  , "Disaster Movie" olan
#    Datasında 9.4 , 9.3 , 8.8 , 8.4 , 3.8 , 2.1 olan bir seri oluşturun.(2 Farklı yolla da oluşturun) (Datayı ve İndexleri liste olarak göndererek ve doğrudan dictionary göndererek.)
#
#
# 2) donem1_mat adında bir seri oluşturun. Bu serinin içinde "Ali" ,"Deniz" ,"Aslı" ,"Burak" ,"Kerem" ,"Yasemin" ,"Derya" index değerleri olsun,
#    85, 80 , 94 , 74 , 91 , 96 , 70 data değerleri olsun. Bu şekilde donem1 adında öğrencilerin 1.dönem matematik nor ortalamalarının tutulduğu bir seri oluşturun.
#
#    donem2_mat adında başka bir seri oluşturun. Okula yeni bir öğrenci gelmiş olsun ve indexlerde bu sefer "Ali" ,"Deniz" ,"Aslı" ,"Burak" ,"Kerem" ,"Yasemin" ,"Derya" ,"Mert"         indexleri olsun. 80, 92 , 85 , 87, 90 , 92, 100, 83 ise dataları olsun. Bu iki seriyi birleştirerek bütün öğrencilerin yıl sonu matematik ORTALAMASINI hesaplayın.
#
#    Not : Eğer bir öğrencinin sadece ikinci dönem notu bulunuyorsa, birinci dönem hesaba eklenmeden ikinci dönem notu yıl sonu notu olarak hesaplansın.
#
#
# 3) İndexlerinde "Osman", "Ozlem", "İnci", "Koray", "Melek" olan, columnlarında "Sınıf" , "Cinsiyet" , "Favori Ders" isimlerinde 3 column bulunan bir DF oluşturacaksınız. Osman'ın sınıfı 8 , cinsiyeti "E" , Favori Dersi "Fen"
# Ozlem'in sınıfı 11 , cinsiyeti "K" , Favori Dersi "Mat"
# İnci'nin sınıfı 5 , cinsiyeti "K" , Favori Dersi "Sosyal"
# Koray'ın sınıfı 9 , cinsiyeti "E" , Favori Dersi "Mat"
# Meleğin sınıfı 7 , cinsiyeti "K" , Favori Dersi "Ing"          Olacak şekilde bir df oluşturun.
#
# 4) GitHubda bulunan "Advertising.csv" reklam datasını herhangi bir platformda DF olarak okuyun ve "df_adv" adında bir değişkene atayın. Ardından df_adv değişkeninin ilk 3 satırına, son 3 satırına , rastgele 3 satırına bakın.
#
# 5) Elde ettiğiniz "df_adv" infosuna ve describe'ına bakın ve yorumlamaya çalışın.
#
# 6) df_adv içinden sadece "TV" sütununu seri olarak çekin.
#
# 7) df_adv içinden "TV" ve "sales" sütununu çekin ve df_salesTV adında bir değişkene atayın.
#
# 8) df_adv içindeki "TV" , "radio" , "newspaper" sütunlarındaki değerleri toplayarak "total_adv" adında yeni bir sütun oluşturun.
#
# 9) df_adv içindeki "sales" sütununun drop edilmiş halini ekrana yazdırın. (Kalıcı hale getirmeyin. Sadece ekrana bastırın)
#
# 10) df_adv içindeki son 50 index'i(satırı) çekin ve ekrana yazdırın.
#
# 11) df_adv içinde satışları 25'den fazla olanları getirin.
#
# 12) df_adv içinde "TV" reklamlarına 250'den fazla VE "newspaper" reklamlarına 60'dan fazla harcama yapanları getirin.
#
# 13) df_adv içinde "newspaper" reklam harcamaları 70'den fazla VEYA "radio" reklam harcamaları 50'den fazla olanları getirin.
#
# 14) df_adv içinde "sales" ları 10 ile 15(10 ve 15 dahil) arasında olanları getirin.
#
# 15) df_adv içinde "sales" ları tam olarak 18.3 veya 14.0 veya 25.5 veya 21.7 veya 13.6 veya 6.9 olanları getirin.
#
# 16) GitHubda bulunan "tips.csv" restoran datasını "df_tips" adıyla okuyun. Ardından ilk 5 satırına bakın.
#
# 17) df_tips'in "CC Number" ve "Payment ID" column'larını kalıcı olarak düşürün.
#
# 18) df_tips'in "Payer Name" column'unu kalıcı olarak index yapın ve artık columndan düşürün.
#
# 19) df_tips içindeki kayıtlardan kişi sayısı 4 veya 4'den fazla olan siparişlerin kaç tane olduğunu bulun.(Sorguyu yazıp istediğimiz satırları getirdikten sonra basitçe len() fonksiyonunu kullanarak sayılarını bulabilirsiniz. Veya daha güzeli .shape[0] yaparak elde ettiğiniz sorguda kaç satır olduğunun sayısına ulaşabilirsiniz.)
#
# 20) df_tips içindeki Kişi sayısı 2 ya da 3 olan, sigara içen, erkek olan ve ödediği ücret 20 dolardan az olan kişi sayısını bulalım.

# %%
import numpy as np
import pandas as pd

# %%
"""
  1) İndexlerinde "Breaking Bad" , "Chernobyl" , "Leyla ile Mecnun" , "X-Men" , "Captain America" , "Disaster Movie" olan Datasında 9.4 , 9.3 , 8.8 , 8.4 , 3.8 , 2.1 olan bir seri oluşturun.
  (2 Farklı yolla da oluşturun) (Datayı ve İndexleri liste olarak göndererek ve doğrudan dictionary göndererek.)
"""
dizi_index = np.array(["Breaking Bad" , "Chernobyl" , "Leyla ile Mecnun" , "X-Men" , "Captain America" , "Disaster Movie"])
dizi_data = np.array([9.4 , 9.3 , 8.8 , 8.4 , 3.8 , 2.1])
dizi_columns = np.array(["Rating"])
dizi = pd.DataFrame(data = dizi_data , index = dizi_index , columns = dizi_columns)
print(dizi)
print("\n")

dizi_dict = {}
for key, value in dizi.iterrows():
  dizi_dict[key] = value[0]

print(dizi_dict)
print("\n")

dizi = pd.Series(data = dizi_dict)
print(dizi)
# Out:
#                   Rating
# Breaking Bad         9.4
# Chernobyl            9.3
# Leyla ile Mecnun     8.8
# X-Men                8.4
# Captain America      3.8
# Disaster Movie       2.1
#
#
# {'Breaking Bad': 9.4, 'Chernobyl': 9.3, 'Leyla ile Mecnun': 8.8, 'X-Men': 8.4, 'Captain America': 3.8, 'Disaster Movie': 2.1}
#
#
# Breaking Bad        9.4
# Chernobyl           9.3
# Leyla ile Mecnun    8.8
# X-Men               8.4
# Captain America     3.8
# Disaster Movie      2.1
# dtype: float64

# %%
"""
  2) donem1_mat adında bir seri oluşturun. Bu serinin içinde "Ali" ,"Deniz" ,"Aslı" ,"Burak" ,"Kerem" ,"Yasemin" ,"Derya" index değerleri olsun, 85, 80 , 94 , 74 , 91 , 96 , 70 data değerleri olsun.
  Bu şekilde donem1 adında öğrencilerin 1.dönem matematik nor ortalamalarının tutulduğu bir seri oluşturun. 
  donem2_mat adında başka bir seri oluşturun. Okula yeni bir öğrenci gelmiş olsun ve indexlerde bu sefer "Ali" ,"Deniz" ,"Aslı" ,"Burak" ,"Kerem" ,"Yasemin" ,"Derya" ,"Mert" indexleri olsun.
  80, 92 , 85 , 87, 90 , 92, 100, 83 ise dataları olsun. Bu iki seriyi birleştirerek bütün öğrencilerin yıl sonu matematik ORTALAMASINI hesaplayın.
  Not : Eğer bir öğrencinin sadece ikinci dönem notu bulunuyorsa, birinci dönem hesaba eklenmeden ikinci dönem notu yıl sonu notu olarak hesaplansın.
"""

donem1_mat_index = np.array(["Ali" ,"Deniz" ,"Aslı" ,"Burak" ,"Kerem" ,"Yasemin" ,"Derya"])
donem1_mat_data = np.array([85, 80 , 94 , 74 , 91 , 96 , 70])

donem2_mat_index = np.array(["Ali" ,"Deniz" ,"Aslı" ,"Burak" ,"Kerem" ,"Yasemin" ,"Derya" ,"Mert"])
donem2_mat_data = np.array([80, 92 , 85 , 87, 90 , 92, 100, 83])

donem1_mat = pd.Series(data = donem1_mat_data , index = donem1_mat_index)
donem2_mat = pd.Series(data = donem2_mat_data , index = donem2_mat_index)

donem_mat = pd.concat([donem1_mat,donem2_mat] , join="outer", sort=True , axis=1 , verify_integrity = True , )
donem_mat.columns = ["Dönem 1", "Dönem 2"]
donem_mat = donem_mat.reindex(columns=["Dönem 1", "Dönem 2", "Ortalama"])

#donem_mat.insert(loc = 2, column = "Ortalama" , value = donem_mat.mean(axis=1, numeric_only=True)) / Kısa Çözüm

if donem_mat["Dönem 1"].isnull().values.any():
  df_null = donem_mat.loc[donem_mat["Dönem 1"].isnull()].copy()
  for i in df_null.index:
    donem_mat.at[i, "Dönem 1"] = donem_mat.at[i, "Dönem 2"]

donem_mat["Ortalama"] = (donem_mat["Dönem 1"] + donem_mat["Dönem 2"]) / 2

print(donem_mat)
# Out:
#          Dönem 1  Dönem 2  Ortalama
# Ali         85.0       80      82.5
# Aslı        94.0       85      89.5
# Burak       74.0       87      80.5
# Deniz       80.0       92      86.0
# Derya       70.0      100      85.0
# Kerem       91.0       90      90.5
# Mert        83.0       83      83.0
# Yasemin     96.0       92      94.0

# %%
"""
  3) İndexlerinde "Osman", "Ozlem", "İnci", "Koray", "Melek" olan, columnlarında "Sınıf" , "Cinsiyet" , "Favori Ders" isimlerinde 3 column bulunan bir DF oluşturacaksınız. Osman'ın sınıfı 8 , cinsiyeti "E" ,
  Favori Dersi "Fen" Ozlem'in sınıfı 11 , cinsiyeti "K" , Favori Dersi "Mat" İnci'nin sınıfı 5 , cinsiyeti "K" , Favori Dersi "Sosyal" Koray'ın sınıfı 9 , cinsiyeti "E" , Favori Dersi "Mat" Meleğin sınıfı 7 ,
  cinsiyeti "K" , Favori Dersi "Ing" Olacak şekilde bir df oluşturun.
"""

df_columns = np.array(["Sınıf" , "Cinsiyet" , "Favori Ders"])
df_data = {"Osman": [8,"E", "Fen"],
           "Ozlem": [11,"K", "Mat"],
           "İnci": [5,"K", "Sosyal"],
           "Koray": [9,"E", "Mat"],
           "Melek": [7,"K", "Ing"], 
          }

df = pd.DataFrame.from_dict(data = df_data , orient='index' , columns = df_columns)
print(df)
# Out:
#        Sınıf Cinsiyet Favori Ders
# Osman      8        E         Fen
# Ozlem     11        K         Mat
# İnci       5        K      Sosyal
# Koray      9        E         Mat
# Melek      7        K         Ing

# %%
"""
  4) GitHubda bulunan "Advertising.csv" reklam datasını herhangi bir platformda DF olarak okuyun ve "df_adv" adında bir değişkene atayın.
  Ardından df_adv değişkeninin ilk 3 satırına, son 3 satırına , rastgele 3 satırına bakın.
"""

url = 'https://github.com/csargin/Ders-Notebooklari/blob/main/Pandas-Dersleri/Advertising.csv?raw=true'
df_adv = pd.read_csv(filepath_or_buffer = url , on_bad_lines='skip')

print(df_adv.head(3))
print(df_adv.tail(3))
print(df_adv.sample(3))
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
#         TV  radio  newspaper  sales
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#        TV  radio  newspaper  sales
# 58  210.8   49.6       37.7   23.8
# 8     8.6    2.1        1.0    4.8
# 45  175.1   22.5       31.5   14.9

# %%
#5) Elde ettiğiniz "df_adv" infosuna ve describe'ına bakın ve yorumlamaya çalışın

print(df_adv.info())
print(df_adv.describe().T)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   radio      200 non-null    float64
#  2   newspaper  200 non-null    float64
#  3   sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB
# None
#            count      mean        std  min     25%     50%      75%    max
# TV         200.0  147.0425  85.854236  0.7  74.375  149.75  218.825  296.4
# radio      200.0   23.2640  14.846809  0.0   9.975   22.90   36.525   49.6
# newspaper  200.0   30.5540  21.778621  0.3  12.750   25.75   45.100  114.0
# sales      200.0   14.0225   5.217457  1.6  10.375   12.90   17.400   27.0

# %%
#6) df_adv içinden sadece "TV" sütununu seri olarak çekin.

print(df_adv[["TV"]])
# Out:
#         TV
# 0    230.1
# 1     44.5
# 2     17.2
# 3    151.5
# 4    180.8
# ..     ...
# 195   38.2
# 196   94.2
# 197  177.0
# 198  283.6
# 199  232.1
#
# [200 rows x 1 columns]

# %%
#7) df_adv içinden "TV" ve "sales" sütununu çekin ve df_salesTV adında bir değişkene atayın.

df_salesTV = df_adv[["TV","sales"]]
print(df_salesTV)
# Out:
#         TV  sales
# 0    230.1   22.1
# 1     44.5   10.4
# 2     17.2    9.3
# 3    151.5   18.5
# 4    180.8   12.9
# ..     ...    ...
# 195   38.2    7.6
# 196   94.2    9.7
# 197  177.0   12.8
# 198  283.6   25.5
# 199  232.1   13.4
#
# [200 rows x 2 columns]

# %%
#8) df_adv içindeki "TV" , "radio" , "newspaper" sütunlarındaki değerleri toplayarak "total_adv" adında yeni bir sütun oluşturun.

df_adv['total_adv'] = df_adv["TV"] + df_adv["radio"] +df_adv["newspaper"]
print(df)
# Out:
#        Sınıf Cinsiyet Favori Ders
# Osman      8        E         Fen
# Ozlem     11        K         Mat
# İnci       5        K      Sosyal
# Koray      9        E         Mat
# Melek      7        K         Ing

# %%
#9) df_adv içindeki "sales" sütununun drop edilmiş halini ekrana yazdırın. (Kalıcı hale getirmeyin. Sadece ekrana bastırın)

print(df_adv.drop(columns = "sales", inplace = False))
# Out:
#         TV  radio  newspaper  total_adv
# 0    230.1   37.8       69.2      337.1
# 1     44.5   39.3       45.1      128.9
# 2     17.2   45.9       69.3      132.4
# 3    151.5   41.3       58.5      251.3
# 4    180.8   10.8       58.4      250.0
# ..     ...    ...        ...        ...
# 195   38.2    3.7       13.8       55.7
# 196   94.2    4.9        8.1      107.2
# 197  177.0    9.3        6.4      192.7
# 198  283.6   42.0       66.2      391.8
# 199  232.1    8.6        8.7      249.4
#
# [200 rows x 4 columns]

# %%
#10) df_adv içindeki son 50 index'i(satırı) çekin ve ekrana yazdırın.

df = df_adv.tail(50)
df
# Out:
#         TV  radio  newspaper  sales  total_adv
# 150  280.7   13.9       37.0   16.1      331.6
# 151  121.0    8.4       48.7   11.6      178.1
# 152  197.6   23.3       14.2   16.6      235.1
# 153  171.3   39.7       37.7   19.0      248.7
# 154  187.8   21.1        9.5   15.6      218.4
# 155    4.1   11.6        5.7    3.2       21.4
# 156   93.9   43.5       50.5   15.3      187.9
# 157  149.8    1.3       24.3   10.1      175.4
# 158   11.7   36.9       45.2    7.3       93.8
# 159  131.7   18.4       34.6   12.9      184.7
# 160  172.5   18.1       30.7   14.4      221.3
# 161   85.7   35.8       49.3   13.3      170.8
# 162  188.4   18.1       25.6   14.9      232.1
# 163  163.5   36.8        7.4   18.0      207.7
# 164  117.2   14.7        5.4   11.9      137.3
# 165  234.5    3.4       84.8   11.9      322.7
# 166   17.9   37.6       21.6    8.0       77.1
# 167  206.8    5.2       19.4   12.2      231.4
# 168  215.4   23.6       57.6   17.1      296.6
# ...

# %%
#11) df_adv içinde satışları 25'den fazla olanları getirin

df = df_adv[df_adv['sales'] > 25]     
df
# Out:
#         TV  radio  newspaper  sales  total_adv
# 36   266.9   43.8        5.0   25.4      315.7
# 98   289.7   42.3       51.2   25.4      383.2
# 147  243.2   49.0       44.3   25.4      336.5
# 175  276.9   48.9       41.8   27.0      367.6
# 183  287.6   43.0       71.8   26.2      402.4
# 198  283.6   42.0       66.2   25.5      391.8

# %%
#12) df_adv içinde "TV" reklamlarına 250'den fazla VE "newspaper" reklamlarına 60'dan fazla harcama yapanları getirin.

df = df_adv[(df_adv['TV'] > 250) & (df_adv['newspaper'] > 60) ]     
df
# Out:
#         TV  radio  newspaper  sales  total_adv
# 93   250.9   36.5       72.3   22.2      359.7
# 101  296.4   36.3      100.9   23.8      433.6
# 183  287.6   43.0       71.8   26.2      402.4
# 198  283.6   42.0       66.2   25.5      391.8

# %%
#13) df_adv içinde "newspaper" reklam harcamaları 70'den fazla VEYA "radio" reklam harcamaları 50'den fazla olanları getirin.

df = df_adv[(df_adv['radio'] > 50) | (df_adv['newspaper'] > 70) ]     
df
# Out:
#         TV  radio  newspaper  sales  total_adv
# 5      8.7   48.9       75.0    7.2      132.6
# 16    67.8   36.6      114.0   12.5      218.4
# 75    16.9   43.7       89.4    8.7      150.0
# 88    88.3   25.5       73.4   12.9      187.2
# 93   250.9   36.5       72.3   22.2      359.7
# 101  296.4   36.3      100.9   23.8      433.6
# 118  125.7   36.9       79.2   15.9      241.8
# 124  229.5   32.3       74.2   19.7      336.0
# 141  193.7   35.4       75.6   19.2      304.7
# 165  234.5    3.4       84.8   11.9      322.7
# 183  287.6   43.0       71.8   26.2      402.4

# %%
#14) df_adv içinde "sales" ları 10 ile 15(10 ve 15 dahil) arasında olanları getirin.

df = df_adv[(df_adv['sales'] >= 10) & (df_adv['sales'] <= 15) ]     
df
# Out:
#         TV  radio  newspaper  sales  total_adv
# 1     44.5   39.3       45.1   10.4      128.9
# 4    180.8   10.8       58.4   12.9      250.0
# 6     57.5   32.8       23.5   11.8      113.8
# 7    120.2   19.6       11.6   13.2      151.4
# 9    199.8    2.6       21.2   10.6      223.6
# ..     ...    ...        ...    ...        ...
# 181  218.5    5.4       27.4   12.2      251.3
# 186  139.5    2.1       26.6   10.3      168.2
# 190   39.5   41.1        5.8   10.8       86.4
# 197  177.0    9.3        6.4   12.8      192.7
# 199  232.1    8.6        8.7   13.4      249.4
#
# [80 rows x 5 columns]

# %%
#15) df_adv içinde "sales" ları tam olarak 18.3 veya 14.0 veya 25.5 veya 21.7 veya 13.6 veya 6.9 olanları getirin.

df = df_adv[(df_adv['sales'] == 18.3) | (df_adv['sales'] == 14.0) | (df_adv['sales'] == 25.5)  | (df_adv['sales'] == 21.7) | (df_adv['sales'] == 13.6)  | (df_adv['sales'] == 6.9)  ]     
df
# Out:
#         TV  radio  newspaper  sales  total_adv
# 63   102.7   29.6        8.4   14.0      140.7
# 70   199.1   30.6       38.7   18.3      268.4
# 76    27.5    1.6       20.7    6.9       49.8
# 83    68.4   44.5       35.6   13.6      148.5
# 84   213.5   43.0       33.8   21.7      290.3
# 198  283.6   42.0       66.2   25.5      391.8

# %%
#16) GitHubda bulunan "tips.csv" restoran datasını "df_tips" adıyla okuyun. Ardından ilk 5 satırına bakın.

url = 'https://github.com/csargin/Ders-Notebooklari/blob/main/Pandas-Dersleri/tips.csv?raw=true'
df_tips =  pd.read_csv(filepath_or_buffer = url , on_bad_lines='skip')

df_tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
#17) df_tips'in "CC Number" ve "Payment ID" column'larını kalıcı olarak düşürün.

df_tips.drop(columns = ["CC Number", "Payment ID"], inplace = True)
df_tips
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name
# 0    Christy Cunningham
# ...

# %%
#18) df_tips'in "Payer Name" column'unu kalıcı olarak index yapın ve artık columndan düşürün.

df_tips.set_index("Payer Name", inplace = True, drop=True,)
df_tips
# Out:
#                     total_bill   tip     sex smoker   day    time  size  \
# Payer Name
# Christy Cunningham       16.99  1.01  Female     No   Sun  Dinner     2
# Douglas Tucker           10.34  1.66    Male     No   Sun  Dinner     3
# Travis Walters           21.01  3.50    Male     No   Sun  Dinner     3
# Nathaniel Harris         23.68  3.31    Male     No   Sun  Dinner     2
# Tonya Carter             24.59  3.61  Female     No   Sun  Dinner     4
# ...                        ...   ...     ...    ...   ...     ...   ...
# Michael Avila            29.03  5.92    Male     No   Sat  Dinner     3
# Monica Sanders           27.18  2.00  Female    Yes   Sat  Dinner     2
# Keith Wong               22.67  2.00    Male    Yes   Sat  Dinner     2
# Dennis Dixon             17.82  1.75    Male     No   Sat  Dinner     2
# Michelle Hardin          18.78  3.00  Female     No  Thur  Dinner     2
#
#                     price_per_person
# Payer Name
# Christy Cunningham              8.49
# ...

# %%
"""
  19) df_tips içindeki kayıtlardan kişi sayısı 4 veya 4'den fazla olan siparişlerin kaç tane olduğunu bulun.
  (Sorguyu yazıp istediğimiz satırları getirdikten sonra basitçe len() fonksiyonunu kullanarak sayılarını bulabilirsiniz.
  Veya daha güzeli .shape[0] yaparak elde ettiğiniz sorguda kaç satır olduğunun sayısına ulaşabilirsiniz.)
"""

df = df_tips[(df_tips['size'] >= 4) ]     
print(df.shape[0])
print(len(df))
# Out:
# 46
# 46

# %%
#20) df_tips içindeki Kişi sayısı 2 ya da 3 olan, sigara içen, erkek olan ve ödediği ücret 20 dolardan az olan kişi sayısını bulalım.

df = df_tips[((df_tips['size'] == 2) | (df_tips['size'] == 3)) & (df_tips['smoker'] == "Yes") & (df_tips['sex'] == "Male") & (df_tips['total_bill'] < 20) ]     
df
# Out:
#                    total_bill   tip   sex smoker   day    time  size  \
# Payer Name
# Troy Guerrero           11.24  1.76  Male    Yes   Sat  Dinner     2
# Ryan Hernandez          13.81  2.00  Male    Yes   Sat  Dinner     2
# Joseph Hart             11.02  1.98  Male    Yes   Sat  Dinner     2
# Adam Hall               15.01  2.09  Male    Yes   Sat  Dinner     2
# Mark Smith              17.92  3.08  Male    Yes   Sat  Dinner     2
# Louis Torres            19.44  3.00  Male    Yes  Thur   Lunch     2
# Eric Herrera            12.03  1.50  Male    Yes   Fri  Dinner     2
# David Price             15.36  1.64  Male    Yes   Sat  Dinner     2
# Jason Burgess           16.00  2.00  Male    Yes  Thur   Lunch     2
# David Hall              15.81  3.16  Male    Yes   Sat  Dinner     2
# Larry White              7.25  5.15  Male    Yes   Sun  Dinner     2
# Brian Miles             16.82  4.00  Male    Yes   Sun  Dinner     2
# ...

# %% [markdown]
# # Ödev 2

# %% [markdown]
# 1) df_tips içindeki Payment ID column'unun son 3 rakamını çekin. Bu işlemi 3 farklı yolla da yapmaya çalışın.
# 2) df_tips içindeki Payer Name sütununda isim ve soy isim bilgileri bulunuyor. O sütundan sadece isim bilgileri çekin ve 'JustName' adında yeni bir column oluşturun. (Bu biraz zorlayıcı olabilir, Önce kendiniz yapmaya çalışın fakat yapamazsanız ChatGPT'ye soruyu düzgünce sorarak cevabını kod olarak alabilirsiniz, ardından döndürülen kodu anlamaya çalışmanız yeterlidir.)
# 3) 2.Soruda yeni oluşturduğunuz 'JustName' sütunundaki verilerin her birinden kaç tane olduğuna uygun methodu kullanarak bakın.
# 4) 3.Soruda gördüğünüz gibi JustName sütununda 'Jason' isminden 9 tane, 'Michael' isminden 7 tane , 'James' isminden 6 tane bulunuyor. Peki bunların hepsi gerçekten farklı kişiler mi ? Hemen 'Payer Name' sütunundaki verilerin adetlerini de saydırtarak bir kıyaslama yapın. 'JustName' sütununu kullanmanın faydasız ve yanıltıcı olabileceğini görün ardından oluşturduğumuz 'JustName' sütununu kalıcı olarak drop edin. (Oluşturmanız için bir pratikti bu sütun sadece :D)
# 5) Erkeklerin ve kadınların davranış patternlerini ayrı ayrı inceleyip yorumda bulunabilmek için 'df_male' ve 'df_female' adında 2 dataframe oluşturun. Birinde sadece 157 erkek verisi, diğerinde sadece 87 kadın verisi bulunsun.
# 6) Ardından bu 'df_male' ile 'df_female' 'in ödedikleri bahşişler toplamını bulup karşılaştırın.
# 7) 6.Soruda erkeklerin ve kadınların ödedikleri bahşişler toplamına bakıldığında Erkeklerin kadınlara kıyasla toplamda daha çok bahşiş ödediğini görüyoruz. Fakat biz biliyoruz ki bizim verimizde 157 Erkek, 87 kadın verisi vardı. Dolayısıyla Erkek sayısı daha fazla olduğu için toplam ödeyecekleri bahşiş miktarlarında da daha fazla çıkması oldukça normal bir durum. Bu yüzden daha mantıklı bir çıkarım için bu sefer df_male ile df_female'in bahşiş ORTALAMALARIN'a bakıp kıyaslayın, aralarında anlamlı ve ciddi bir fark var mı ?
# 8) Oluşturmuş olduğunuz df_male ile çalışarak elimizdeki verideki erkeklerin yüzde kaçının sigara içtiğini bulun. Aynı şekilde elimizdeki kadınların yüzde kaçının sigara içtiğini de bulun. Aralarında anlamlı bir fark mı yorumlayın.
# 9) Erkeklerin zaman olarak dinnerda mı yoksa lunch'da mı daha fazla yemek yediğini yüzdesel olarak bulun. Aynı işlemi kadınlar için de yapın. Yüzdesel olarak erkeklerin ve kadınların yemek yeme vakitleri arasında anlamlı bir fark var mı yok mu yorumlayın.
# 10) CC Number sütununu kalıcı olarak drop edin. Ardından df'in içindeki sütunların birbirleriyle olan ilişkilerini inceleyin ve çıkan sonuçlar hakkında yorumlarınızı belirtin.

# %%
import numpy as np
import pandas as pd

url = 'https://github.com/csargin/Ders-Notebooklari/blob/main/Pandas-Dersleri/tips.csv?raw=true'
df_tips =  pd.read_csv(filepath_or_buffer = url , on_bad_lines='skip')

# %%
#1) df_tips içindeki Payment ID column'unun son 3 rakamını çekin. Bu işlemi 3 farklı yolla da yapmaya çalışın.

print(df_tips["Payment ID"].tail(3))
print("\n")
print(df_tips["Payment ID"][-3:])
print("\n")
print(df_tips["Payment ID"].iloc[-3:])
print("\n")
# Out:
# 241    Sat3880
# 242      Sat17
# 243    Thur672
# Name: Payment ID, dtype: object
#
#
# 241    Sat3880
# 242      Sat17
# 243    Thur672
# Name: Payment ID, dtype: object
#
#
# 241    Sat3880
# 242      Sat17
# 243    Thur672
# Name: Payment ID, dtype: object

# %%
"""
  2) df_tips içindeki Payer Name sütununda isim ve soy isim bilgileri bulunuyor. O sütundan sadece isim bilgileri çekin ve 'JustName' adında yeni bir column oluşturun.
  (Bu biraz zorlayıcı olabilir, Önce kendiniz yapmaya çalışın fakat yapamazsanız ChatGPT'ye soruyu düzgünce sorarak cevabını kod olarak alabilirsiniz, ardından döndürülen kodu anlamaya çalışmanız yeterlidir.)
"""

df_tips['JustName'] = df_tips['Payer Name'].str.split().str[0]
print(df_tips)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID   JustName
# ...

# %%
#3) 2.Soruda yeni oluşturduğunuz 'JustName' sütunundaki verilerin her birinden kaç tane olduğuna uygun methodu kullanarak bakın. 
df_tips['JustName'].value_counts()
# Out:
# Jason          9
# Michael        7
# James          6
# David          6
# Christopher    5
#               ..
# Shawna         1
# Louis          1
# Chris          1
# Mark           1
# Michelle       1
# Name: JustName, Length: 153, dtype: int64

# %%
"""
  4) 3.Soruda gördüğünüz gibi JustName sütununda 'Jason' isminden 9 tane, 'Michael' isminden 7 tane , 'James' isminden 6 tane bulunuyor.
  Peki bunların hepsi gerçekten farklı kişiler mi ? Hemen 'Payer Name' sütunundaki verilerin adetlerini de saydırtarak bir kıyaslama yapın.
  'JustName' sütununu kullanmanın faydasız ve yanıltıcı olabileceğini görün ardından oluşturduğumuz 'JustName' sütununu kalıcı olarak drop edin. (Oluşturmanız için bir pratikti bu sütun sadece :D)
"""

df_tips['Payer Name'].value_counts()
df_tips.drop('JustName', axis = 1, inplace = True)
print(df_tips)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
"""
  5) Erkeklerin ve kadınların davranış patternlerini ayrı ayrı inceleyip yorumda bulunabilmek için 'df_male' ve 'df_female' adında 2 dataframe oluşturun.
  Birinde sadece 157 erkek verisi, diğerinde sadece 87 kadın verisi bulunsun.
"""

# Filter for male customers
df_male = df_tips[df_tips['sex'] == 'Male'].sample(n=157, random_state=42)
df_male = df_tips[df_tips['sex'] == 'Male']

# Filter for female customers
df_female = df_tips[df_tips['sex'] == 'Female'].sample(n=87, random_state=42)
df_female = df_tips[df_tips['sex'] == 'Female']

print(df_male.shape)
print(df_female.shape)
# Out:
# (157, 11)
# (87, 11)

# %%
#6) Ardından bu 'df_male' ile 'df_female' 'in ödedikleri bahşişler toplamını bulup karşılaştırın.

print(df_male["tip"].sum())
print(df_female["tip"].sum())
# Out:
# 485.07
# 246.50999999999996

# %%
"""
  7) 6.Soruda erkeklerin ve kadınların ödedikleri bahşişler toplamına bakıldığında Erkeklerin kadınlara kıyasla toplamda daha çok bahşiş ödediğini görüyoruz.
  Fakat biz biliyoruz ki bizim verimizde 157 Erkek, 87 kadın verisi vardı. Dolayısıyla Erkek sayısı daha fazla olduğu için toplam ödeyecekleri bahşiş miktarlarında da daha fazla çıkması oldukça normal bir durum.
  Bu yüzden daha mantıklı bir çıkarım için bu sefer df_male ile df_female'in bahşiş ORTALAMALARIN'a bakıp kıyaslayın, aralarında anlamlı ve ciddi bir fark var mı ?
"""

print(df_male["tip"].mean())
print(df_female["tip"].mean())
# Out:
# 3.0896178343949043
# 2.8334482758620685

# %%
"""
  8) Oluşturmuş olduğunuz df_male ile çalışarak elimizdeki verideki erkeklerin yüzde kaçının sigara içtiğini bulun.
  Aynı şekilde elimizdeki kadınların yüzde kaçının sigara içtiğini de bulun. Aralarında anlamlı bir fark mı yorumlayın.
"""

# Calculate the percentage of male customers who smoke
male_smokers = df_male['smoker'].value_counts(normalize=True)['Yes'] * 100

# Calculate the percentage of female customers who smoke
female_smokers = df_female['smoker'].value_counts(normalize=True)['Yes'] * 100

print("Percentage of male customers who smoke:", male_smokers)
print("Percentage of female customers who smoke:", female_smokers)

# Create contingency table for male and female smokers
contingency_table = pd.crosstab(df_tips['sex'], df_tips['smoker'])
print("contingency_table:", contingency_table)

# Perform chi-squared test on the contingency table
from scipy.stats import chi2_contingency
chi2, p, dof, expected = chi2_contingency(contingency_table)

# print the results
print("Chi-squared value:", chi2)
print("p-value:", p)
print("Degrees of freedom:", dof)
print("Expected frequencies:\n", expected)

"""
  Assuming a significance level of 0.05, if the p-value is less than 0.05, we can reject the null hypothesis that there is no difference in smoking rates between male and female customers,
  and conclude that there is a statistically significant difference. On the other hand, if the p-value is greater than 0.05, we cannot reject the null hypothesis and conclude that there is not a statistically significant difference.
"""
# Out:
# Percentage of male customers who smoke: 38.21656050955414
# Percentage of female customers who smoke: 37.93103448275862
# contingency_table: smoker  No  Yes
# sex
# Female  54   33
# Male    97   60
# Chi-squared value: 0.0
# p-value: 1.0
# Degrees of freedom: 1
# Expected frequencies:
#  [[53.84016393 33.15983607]
#  [97.15983607 59.84016393]]
# '\n  Assuming a significance level of 0.05, if the p-value is less than 0.05, we can reject the null hypothesis that there is no difference in smoking rates between male and female customers,\n  and conclude that there is a statistically significant difference. On the other hand, if the p-value is greater than 0.05, we cannot reject the null hypothesis and conclude that there is not a statistically significant difference.\n'

# %%
"""
  9) Erkeklerin zaman olarak dinnerda mı yoksa lunch'da mı daha fazla yemek yediğini yüzdesel olarak bulun.
  Aynı işlemi kadınlar için de yapın. Yüzdesel olarak erkeklerin ve kadınların yemek yeme vakitleri arasında anlamlı bir fark var mı yok mu yorumlayın.
"""

# Calculate the percentage of male customers who eat dinner
male_dinner = df_male['time'].value_counts(normalize=True)['Dinner'] * 100

# Calculate the percentage of male customers who eat lunch
male_lunch = df_male['time'].value_counts(normalize=True)['Lunch'] * 100

# Calculate the percentage of female customers who eat dinner
female_dinner = df_female['time'].value_counts(normalize=True)['Dinner'] * 100

# Calculate the percentage of female customers who eat lunch
female_lunch = df_female['time'].value_counts(normalize=True)['Lunch'] * 100

print("Percentage of male customers who eat dinner:", male_dinner)
print("Percentage of male customers who eat lunch:", male_lunch)
print("Percentage of female customers who eat dinner:", female_dinner)
print("Percentage of female customers who eat lunch:", female_lunch)

# Create contingency table
contingency_table = pd.crosstab(df_tips['time'], df_tips['sex'])
print("contingency_table:", contingency_table)

# Perform chi-squared test on the contingency table
from scipy.stats import chi2_contingency
chi2, p, dof, expected = chi2_contingency(contingency_table)

# print the results
print("Chi-squared value:", chi2)
print("p-value:", p)
print("Degrees of freedom:", dof)
print("Expected frequencies:\n", expected)

"""
  Assuming a significance level of 0.05, if the p-value is less than 0.05, we can reject the null hypothesis that there is no difference in smoking rates between male and female customers,
  and conclude that there is a statistically significant difference. On the other hand, if the p-value is greater than 0.05, we cannot reject the null hypothesis and conclude that there is not a statistically significant difference.
"""
# Out:
# Percentage of male customers who eat dinner: 78.98089171974523
# Percentage of male customers who eat lunch: 21.019108280254777
# Percentage of female customers who eat dinner: 59.77011494252874
# Percentage of female customers who eat lunch: 40.229885057471265
# contingency_table: sex     Female  Male
# time
# Dinner      52   124
# Lunch       35    33
# Chi-squared value: 9.343808982970623
# p-value: 0.002237400118075248
# Degrees of freedom: 1
# Expected frequencies:
#  [[ 62.75409836 113.24590164]
#  [ 24.24590164  43.75409836]]
# '\n  Assuming a significance level of 0.05, if the p-value is less than 0.05, we can reject the null hypothesis that there is no difference in smoking rates between male and female customers,\n  and conclude that there is a statistically significant difference. On the other hand, if the p-value is greater than 0.05, we cannot reject the null hypothesis and conclude that there is not a statistically significant difference.\n'

# %%
#10) CC Number sütununu kalıcı olarak drop edin. Ardından df'in içindeki sütunların birbirleriyle olan ilişkilerini inceleyin ve çıkan sonuçlar hakkında yorumlarınızı belirtin.

df_tips.drop('CC Number', axis = 1, inplace = True)
print(df_tips.describe())
# Out:
#        total_bill         tip        size  price_per_person
# count  244.000000  244.000000  244.000000        244.000000
# mean    19.785943    2.998279    2.569672          7.888197
# std      8.902412    1.383638    0.951100          2.914234
# min      3.070000    1.000000    1.000000          2.880000
# 25%     13.347500    2.000000    2.000000          5.800000
# 50%     17.795000    2.900000    2.000000          7.255000
# 75%     24.127500    3.562500    3.000000          9.390000
# max     50.810000   10.000000    6.000000         20.270000

# %% [markdown]
# # Ödev 3

# %% [markdown]
# mpg.csv dosyasını okuyun ve df değişkenine atayın.
#
# 1) df'in içindeki sütunların birbirleriyle olan korelasyonlarına(ilişkilerine) bakın.
# 2) mpg sütunu ile diğer sütunların arasındaki korelasyonları özel olarak inceleyin.(Bunu göstermedik ama df.corr() çağırdıktan sonra aynı normal df'lerde olduğu gibi istediğiniz sütunu çağırabiliyorsunuz.)
# 3) cylinders sütununda hangi unique değerler olduğuna liste halinde bakın.
# 4) cylinders sütunundaki unique değerlerin her birinden kaçar adet olduğuna bakın.
# 5) Arabanın modeli 75-80 yılları arasındaki arabaların hepsini getirin.(75 ve 80 dahil)
# 6) horsepower'ı 155-180 arasındaki arabaların hepsini getirin.(155 dahil, 180 dahil değil)(Bu sorguyu yapabilmeniz için horsepower sütununu object durumdan float duruma getirmeniz gerekiyor.)
# 7) Elinizdeki df'i horsepower'a göre büyükten küçüğe sıralayın ardından df'in indexlerini sıfırlayın.
# 8) Elinizdeki df'den en küçük 5 acceralation'a sahip olan arabaları getirin.
#
# --- CIA_Country_Facts.csv dosyasını okuyun ve yeniden df değişkenine atayın.(Artık eski df ile işimiz kalmadığı için aynı ismi verebiliriz.)
# 9) Elimizdeki CIA'in ülkeler hakkında topladığı basit açık kaynak verileri df'inde kaç ülkenin verisi olduğunu bulun.
# 10) Elimizdeki sütunlardan hangilerinde kaçar tane nan veri olduğunu bulun.
# 11) Elimizde tamamen nan değerlerden oluşan bir satır varsa o satırı düşürün.(Tamamen nan değerlerden oluşan bir satır olup olmadığını, herhangi bir satırın düşüp düşmediğini kontrol edin)
# 12) Her Bölgedeki(Region) toplam kişi sayısına bakın.
# 13) Climate değerleri nan olanlar, tüm df'in ortalama climate değeriyle doldurun.(Gerçek bir analiz yapıyor olsaydık bu çok mantıklı bir hareket olmazdı, belki her bulunduğu bölgenin ortalama climate değeriyle doldurmak daha mantıklı bir hareket olurdu. Fakat şimdilik bu kadar kasmaya gerek yok. nan değerleri tüm climate ortalamalarıyla doldursanız yeterli.)
# 14) Bölgeler ve Ülkelere göre gruplama yapın ardından Doğum miktarlarına bakın.
# 15) Veriyi istediğiniz şekilde inceleyerek bu zamana kadar öğrendiğiniz bilgilerle anlamlı 5 adet yargı cümlesi çıkartın. ( En çok insan Asya kıtasında yaşıyor, En çok insan Afrinın sahralarında ölüyor, Ortalama en yüksek telefon sahibi Kuzey Amerikada, En çok okuma yazma oranına sahip ülkeler Baltık ülkeleri vb.)

# %%
import numpy as np
import pandas as pd

url = 'https://github.com/csargin/Ders-Notebooklari/blob/main/Pandas-Dersleri/mpg.csv?raw=true'
df_mpg =  pd.read_csv(filepath_or_buffer = url , on_bad_lines='skip')
df_mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   name          398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
# df'in içindeki sütunların birbirleriyle olan korelasyonlarına(ilişkilerine) bakın. 
print(df_mpg.corr())
# Out:
#                    mpg  cylinders  displacement    weight  acceleration  \
# mpg           1.000000  -0.775396     -0.804203 -0.831741      0.420289
# cylinders    -0.775396   1.000000      0.950721  0.896017     -0.505419
# displacement -0.804203   0.950721      1.000000  0.932824     -0.543684
# weight       -0.831741   0.896017      0.932824  1.000000     -0.417457
# acceleration  0.420289  -0.505419     -0.543684 -0.417457      1.000000
# model_year    0.579267  -0.348746     -0.370164 -0.306564      0.288137
# origin        0.563450  -0.562543     -0.609409 -0.581024      0.205873
#
#               model_year    origin
# mpg             0.579267  0.563450
# cylinders      -0.348746 -0.562543
# displacement   -0.370164 -0.609409
# weight         -0.306564 -0.581024
# acceleration    0.288137  0.205873
# model_year      1.000000  0.180662
# origin          0.180662  1.000000

# %%
#2) mpg sütunu ile diğer sütunların arasındaki korelasyonları özel olarak inceleyin.(Bunu göstermedik ama df.corr() çağırdıktan sonra aynı normal df'lerde olduğu gibi istediğiniz sütunu çağırabiliyorsunuz.)
print(df_mpg.corr()["mpg"])
# Out:
# mpg             1.000000
# cylinders      -0.775396
# displacement   -0.804203
# weight         -0.831741
# acceleration    0.420289
# model_year      0.579267
# origin          0.563450
# Name: mpg, dtype: float64

# %%
#3) cylinders sütununda hangi unique değerler olduğuna liste halinde bakın.
print(df_mpg["cylinders"].unique())
# Out:
# [8 4 6 3 5]

# %%
#4) cylinders sütunundaki unique değerlerin her birinden kaçar adet olduğuna bakın.
print(df_mpg["cylinders"].nunique())
print(df_mpg["cylinders"].value_counts())
# Out:
# 5
# 4    204
# 8    103
# 6     84
# 3      4
# 5      3
# Name: cylinders, dtype: int64

# %%
#5) Arabanın modeli 75-80 yılları arasındaki arabaların hepsini getirin.(75 ve 80 dahil)
print(df_mpg[(df_mpg['model_year'] >= 75) & (df_mpg['model_year'] <= 80) ])
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 152  19.0          6         225.0         95    3264          16.0
# 153  18.0          6         250.0        105    3459          16.0
# 154  15.0          6         250.0         72    3432          21.0
# 155  15.0          6         250.0         72    3158          19.5
# 156  16.0          8         400.0        170    4668          11.5
# ..    ...        ...           ...        ...     ...           ...
# 333  32.7          6         168.0        132    2910          11.4
# 334  23.7          3          70.0        100    2420          12.5
# 335  35.0          4         122.0         88    2500          15.1
# 336  23.6          4         140.0          ?    2905          14.3
# 337  32.4          4         107.0         72    2290          17.0
#
#      model_year  origin                     name
# 152          75       1  plymouth valiant custom
# 153          75       1           chevrolet nova
# ...

# %%
#6) horsepower'ı 155-180 arasındaki arabaların hepsini getirin.(155 dahil, 180 dahil değil)(Bu sorguyu yapabilmeniz için horsepower sütununu object durumdan float duruma getirmeniz gerekiyor.)
df_mpg['horsepower'] = df_mpg['horsepower'].replace('?', np.nan).astype(float)
print(df_mpg[(df_mpg['horsepower'] >= 155) & (df_mpg['horsepower'] < 180) ])
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 1    15.0          8         350.0       165.0    3693          11.5
# 10   15.0          8         383.0       170.0    3563          10.0
# 11   14.0          8         340.0       160.0    3609           8.0
# 38   14.0          8         350.0       165.0    4209          12.0
# 39   14.0          8         400.0       175.0    4464          11.5
# 43   13.0          8         400.0       170.0    4746          12.0
# 44   13.0          8         400.0       175.0    5140          12.0
# 62   13.0          8         350.0       165.0    4274          12.0
# 63   14.0          8         400.0       175.0    4385          12.0
# 68   13.0          8         350.0       155.0    4502          13.5
# 69   12.0          8         350.0       160.0    4456          13.5
# 85   13.0          8         350.0       175.0    4100          13.0
# 92   13.0          8         351.0       158.0    4363          13.0
# ...

# %%
# 7) Elinizdeki df'i horsepower'a göre büyükten küçüğe sıralayın ardından df'in indexlerini sıfırlayın. 
df_mpg.sort_values('horsepower')
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 133  16.0          6         250.0        100    3781          17.0
# 98   16.0          6         250.0        100    3278          18.0
# 256  20.5          6         225.0        100    3430          17.2
# 107  18.0          6         232.0        100    2789          15.0
# 334  23.7          3          70.0        100    2420          12.5
# ..    ...        ...           ...        ...     ...           ...
# 126  21.0          6         200.0          ?    2875          17.0
# 374  23.0          4         151.0          ?    3035          20.5
# 354  34.5          4         100.0          ?    2320          15.8
# 32   25.0          4          98.0          ?    2046          19.0
# 336  23.6          4         140.0          ?    2905          14.3
#
#      model_year  origin                               name
# 133          74       1  chevrolet chevelle malibu classic
# ...

# %%
# 8) Elinizdeki df'den en küçük 5 acceralation'a sahip olan arabaları getirin.
print(df_mpg.sort_values('acceleration').head(5))
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 11   14.0          8         340.0       160.0    3609           8.0
# 9    15.0          8         390.0       190.0    3850           8.5
# 7    14.0          8         440.0       215.0    4312           8.5
# 6    14.0          8         454.0       220.0    4354           9.0
# 116  16.0          8         400.0       230.0    4278           9.5
#
#      model_year  origin                name
# 11           70       1  plymouth 'cuda 340
# 9            70       1  amc ambassador dpl
# 7            70       1   plymouth fury iii
# 6            70       1    chevrolet impala
# 116          73       1  pontiac grand prix

# %%
# --- CIA_Country_Facts.csv dosyasını okuyun ve yeniden df değişkenine atayın.(Artık eski df ile işimiz kalmadığı için aynı ismi verebiliriz.)
import numpy as np
import pandas as pd

url = 'https://github.com/csargin/Ders-Notebooklari/blob/main/Pandas-Dersleri/CIA_Country_Facts.csv?raw=true'
df_CIA_Country_Facts =  pd.read_csv(filepath_or_buffer = url , on_bad_lines='skip')
df_CIA_Country_Facts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 20 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Country                             227 non-null    object
#  1   Region                              227 non-null    object
#  2   Population                          227 non-null    int64
#  3   Area (sq. mi.)                      227 non-null    int64
#  4   Pop. Density (per sq. mi.)          227 non-null    float64
#  5   Coastline (coast/area ratio)        227 non-null    float64
#  6   Net migration                       224 non-null    float64
#  7   Infant mortality (per 1000 births)  224 non-null    float64
#  8   GDP ($ per capita)                  226 non-null    float64
#  9   Literacy (%)                        209 non-null    float64
#  10  Phones (per 1000)                   223 non-null    float64
# ...

# %%
 #9) Elimizdeki CIA'in ülkeler hakkında topladığı basit açık kaynak verileri df'inde kaç ülkenin verisi olduğunu bulun. 
 print(df_CIA_Country_Facts["Country"].nunique())
# Out:
# 227

# %%
#10) Elimizdeki sütunlardan hangilerinde kaçar tane nan veri olduğunu bulun.
print(df_CIA_Country_Facts.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 20 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Country                             227 non-null    object
#  1   Region                              227 non-null    object
#  2   Population                          227 non-null    int64
#  3   Area (sq. mi.)                      227 non-null    int64
#  4   Pop. Density (per sq. mi.)          227 non-null    float64
#  5   Coastline (coast/area ratio)        227 non-null    float64
#  6   Net migration                       224 non-null    float64
#  7   Infant mortality (per 1000 births)  224 non-null    float64
#  8   GDP ($ per capita)                  226 non-null    float64
#  9   Literacy (%)                        209 non-null    float64
#  10  Phones (per 1000)                   223 non-null    float64
# ...

# %%
#11) Elimizde tamamen nan değerlerden oluşan bir satır varsa o satırı düşürün.(Tamamen nan değerlerden oluşan bir satır olup olmadığını, herhangi bir satırın düşüp düşmediğini kontrol edin) 
df_CIA_Country_Facts[df_CIA_Country_Facts.isna().any(axis=1)]
# Out:
#                   Country                               Region  Population  \
# 3          American Samoa  OCEANIA                                   57794
# 4                 Andorra  WESTERN EUROPE                            71201
# 5                  Angola  SUB-SAHARAN AFRICA                     12127071
# 25   Bosnia & Herzegovina  EASTERN EUROPE                          4498976
# 36                 Canada  NORTHERN AMERICA                       33098932
# 47           Cook Islands  OCEANIA                                   21388
# 50                Croatia  EASTERN EUROPE                          4494749
# 52                 Cyprus  NEAR EAST                                784301
# 58             East Timor        ASIA (EX. NEAR EAST)              1062777
# 66          Faroe Islands  WESTERN EUROPE                            47246
# 74             Gaza Strip  NEAR EAST                               1428757
# ...

# %%
#12) Her Bölgedeki(Region) toplam kişi sayısına bakın. 
for r in df_CIA_Country_Facts['Region'].unique():
  print(df_CIA_Country_Facts.loc[df_CIA_Country_Facts['Region'] == r, 'Population'].sum())
# Out:
# 3687982236
# 119914717
# 161407133
# 33131662
# 396339998
# 749437000
# 561824599
# 280081548
# 195068377
# 331672307
# 7184974

# %%
"""
13) Climate değerleri nan olanlar, tüm df'in ortalama climate değeriyle doldurun.
(Gerçek bir analiz yapıyor olsaydık bu çok mantıklı bir hareket olmazdı, belki her bulunduğu bölgenin ortalama climate değeriyle doldurmak daha mantıklı bir hareket olurdu.
Fakat şimdilik bu kadar kasmaya gerek yok. nan değerleri tüm climate ortalamalarıyla doldursanız yeterli.)
"""
df_CIA_Country_Facts['Climate'].fillna(df_CIA_Country_Facts['Climate'].mean())
# Out:
# 0      1.0
# 1      3.0
# 2      1.0
# 3      2.0
# 4      3.0
#       ...
# 222    3.0
# 223    1.0
# 224    1.0
# 225    2.0
# 226    2.0
# Name: Climate, Length: 227, dtype: float64

# %%
#14) Bölgeler ve Ülkelere göre gruplama yapın ardından Doğum miktarlarına bakın.
df_CIA_Country_Facts.groupby(["Region", "Country"]).mean()['Birthrate']
# Out:
# Region                               Country
# ASIA (EX. NEAR EAST)                 Afghanistan       46.60
#                                      Bangladesh        29.80
#                                      Bhutan            33.65
#                                      Brunei            18.79
#                                      Burma             17.91
#                                                        ...
# WESTERN EUROPE                       San Marino        10.02
#                                      Spain             10.06
#                                      Sweden            10.27
#                                      Switzerland        9.71
#                                      United Kingdom    10.71
# Name: Birthrate, Length: 227, dtype: float64

# %%
"""
15) Veriyi istediğiniz şekilde inceleyerek bu zamana kadar öğrendiğiniz bilgilerle anlamlı 5 adet yargı cümlesi çıkartın.
( En çok insan Asya kıtasında yaşıyor, En çok insan Afrinın sahralarında ölüyor, Ortalama en yüksek telefon sahibi Kuzey Amerikada,
En çok okuma yazma oranına sahip ülkeler Baltık ülkeleri vb.)
"""
